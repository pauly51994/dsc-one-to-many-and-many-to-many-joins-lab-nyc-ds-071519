# %% [markdown]
# # One-to-Many and Many-to-Many Joins - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge on one-to-many and many-to-many relationships!

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Query data using one-to-many and many-to-many joins
# - Predict the resulting size of one-to-many and many-to-many joins

# %% [markdown]
# ## One-to-Many and Many-to-Many Joins
# <img src='images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connect to the Database

# %%
#Your code here
import pandas as pd
import sqlite3

conn = sqlite3.connect('data.sqlite')
c = conn.cursor()

# %% [markdown]
# ## Employees and their Office (a One-to-One join)
#
# Return a list of all of the employees with their first name, last name and the city and state of the office that they work out of (if they have one). Include all employees and order them by their first name, then their last name.

# %%
#Your code here
c.execute("""SELECT e.firstName, e.lastName, o.city, o.state FROM employees e
                JOIN offices o USING(officeCode)
                ORDER BY e.firstName ASC, e.lastName ASC""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#    firstName   lastName           city       state
# 0       Andy     Fixter         Sydney
# 1    Anthony        Bow  San Francisco          CA
# 2      Barry      Jones         London
# 3      Diane     Murphy  San Francisco          CA
# 4   Foon Yue      Tseng            NYC          NY
# 5     George     Vanauf            NYC          NY
# 6     Gerard     Bondur          Paris
# 7     Gerard  Hernandez          Paris
# 8       Jeff   Firrelli  San Francisco          CA
# 9      Julie   Firrelli         Boston          MA
# 10     Larry       Bott         London
# 11    Leslie   Jennings  San Francisco          CA
# 12    Leslie   Thompson  San Francisco          CA
# 13      Loui     Bondur          Paris
# 14      Mami      Nishi          Tokyo  Chiyoda-Ku
# 15    Martin     Gerard          Paris
# 16      Mary  Patterson  San Francisco          CA
# 17    Pamela   Castillo          Paris
# 18     Peter      Marsh         Sydney
# 19     Steve  Patterson         Boston          MA
# 20       Tom       King         Sydney
# 21   William  Patterson         Sydney
# 22   Yoshimi       Kato          Tokyo  Chiyoda-Ku

# %% [markdown]
# ## Customers and their Orders (a One-to-Many join)
#
# Return a list of all the customers first and last names along with a record for each of their order numbers, order dates and statuses.

# %%
# Your code here
c.execute("""SELECT c.contactFirstName, 
                    c.contactLastName, 
                    o.orderNumber, 
                    o.orderDate, 
                    o.status 
                FROM orders o
                JOIN customers c USING(customerNumber)
                ORDER BY c.contactFirstName""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df.tail()
# Out:
#     contactFirstName contactLastName orderNumber   orderDate   status
# 321             Wing           Huang       10365  2005-01-07  Shipped
# 322           Yoshi           Tamuri       10206  2003-12-05  Shipped
# 323           Yoshi           Tamuri       10313  2004-10-22  Shipped
# 324               Yu            Choi       10242  2004-04-20  Shipped
# 325               Yu            Choi       10319  2004-11-03  Shipped

# %% [markdown]
# ## Customers and their Payments (another One-to-Many join)
#
# Return a list of customers first and last names along with details about their payments including the amount and date of payments. Sort these results in descending order by the payment amount.

# %%
# Your code here
c.execute("""SELECT c.contactFirstName,
                    c.contactLastName,
                    amount,
                    paymentDate
                FROM customers c
                JOIN payments p USING(customerNumber)
                ORDER BY contactFirstName, amount DESC""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df.head()
# Out:
#   contactFirstName contactLastName    amount paymentDate
# 0           Adrian          Huxley  35806.73  2004-08-02
# 1           Adrian          Huxley  31835.36  2005-01-03
# 2           Adrian          Huxley  24013.52  2003-08-03
# 3            Akiko       Shimamura    615.45  2005-05-18
# 4            Akiko       Shimamura  48927.64  2004-11-29

# %% [markdown]
# ## Orders, Order details and Product Details (a Many-to-Many Join)

# %% [markdown]
# Return a list of customer first and last names, product names, quantities, and date ordered for each of the customers and each of their orders. Sort these in descending order by the order date.
#
# Note: This will require joining 4 tables! This can be tricky! Give it a shot, and if you're still stuck, turn to the next section where you'll see how to write subqueries which can make complex queries such as this much simpler!

# %%
# Your code here
# need customers, orders, orderdetails, products
c.execute("""SELECT * FROM customers c
                LEFT JOIN orders o USING(customerNumber)
                LEFT JOIN orderdetails od USING(orderNumber)
                JOIN products p USING(productCode)""")

df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#      customerNumber        customerName contactLastName contactFirstName  \
# 0               103   Atelier graphique         Schmitt          Carine
# 1               103   Atelier graphique         Schmitt          Carine
# 2               103   Atelier graphique         Schmitt          Carine
# 3               103   Atelier graphique         Schmitt          Carine
# 4               103   Atelier graphique         Schmitt          Carine
# 5               103   Atelier graphique         Schmitt          Carine
# 6               103   Atelier graphique         Schmitt          Carine
# 7               112  Signal Gift Stores            King             Jean
# 8               112  Signal Gift Stores            King             Jean
# 9               112  Signal Gift Stores            King             Jean
# 10              112  Signal Gift Stores            King             Jean
# 11              112  Signal Gift Stores            King             Jean
# 12              112  Signal Gift Stores            King             Jean
# 13              112  Signal Gift Stores            King             Jean
# 14              112  Signal Gift Stores            King             Jean
# 15              112  Signal Gift Stores            King             Jean
# 16              112  Signal Gift Stores            King             Jean
# 17              112  Signal Gift Stores            King             Jean
# 18              112  Signal Gift Stores            King             Jean
# 19              112  Signal Gift Stores            King             Jean
# 20              112  Signal Gift Stores            King             Jean
# 21              112  Signal Gift Stores            King             Jean
# 22              112  Signal Gift Stores            King             Jean
# 23              112  Signal Gift Stores            King             Jean
# 24              112  Signal Gift Stores            King             Jean
# 25              112  Signal Gift Stores            King             Jean
# 26              112  Signal Gift Stores            King             Jean
# 27              112  Signal Gift Stores            King             Jean
# 28              112  Signal Gift Stores            King             Jean
# 29              112  Signal Gift Stores            King             Jean
# ...             ...                 ...             ...              ...
# 2966            496   Kelly's Gift Shop         Snowden             Tony
# 2967            496   Kelly's Gift Shop         Snowden             Tony
# 2968            496   Kelly's Gift Shop         Snowden             Tony
# 2969            496   Kelly's Gift Shop         Snowden             Tony
# 2970            496   Kelly's Gift Shop         Snowden             Tony
# 2971            496   Kelly's Gift Shop         Snowden             Tony
# 2972            496   Kelly's Gift Shop         Snowden             Tony
# 2973            496   Kelly's Gift Shop         Snowden             Tony
# 2974            496   Kelly's Gift Shop         Snowden             Tony
# 2975            496   Kelly's Gift Shop         Snowden             Tony
# 2976            496   Kelly's Gift Shop         Snowden             Tony
# 2977            496   Kelly's Gift Shop         Snowden             Tony
# 2978            496   Kelly's Gift Shop         Snowden             Tony
# 2979            496   Kelly's Gift Shop         Snowden             Tony
# 2980            496   Kelly's Gift Shop         Snowden             Tony
# 2981            496   Kelly's Gift Shop         Snowden             Tony
# 2982            496   Kelly's Gift Shop         Snowden             Tony
# 2983            496   Kelly's Gift Shop         Snowden             Tony
# 2984            496   Kelly's Gift Shop         Snowden             Tony
# 2985            496   Kelly's Gift Shop         Snowden             Tony
# 2986            496   Kelly's Gift Shop         Snowden             Tony
# 23              Min Lin Diecast
# 24            Red Start Diecast
# 25         Unimax Art Galleries
# 26         Gearbox Collectibles
# 27     Carousel DieCast Legends
# 28          Second Gear Diecast
# 29      Classic Metal Creations
# ...                         ...
# 2966        Studio M Art Models
# 2967            Min Lin Diecast
# 2968   Highway 66 Mini Classics
# 2969    Motor City Art Classics
# 2970          Red Start Diecast
# 2971       Gearbox Collectibles
# 2972            Min Lin Diecast
# 2973       Unimax Art Galleries
# 2974   Carousel DieCast Legends
# 2975              Exoto Designs
# 2976              Exoto Designs
# 2977    Classic Metal Creations
# 2978   Carousel DieCast Legends
# 2979      Autoart Studio Design
# 2980            Min Lin Diecast
# 2981   Carousel DieCast Legends
# 2982      Autoart Studio Design
# 2983        Studio M Art Models
# 2984          Red Start Diecast
# 2985   Carousel DieCast Legends
# 2986  Welly Diecast Productions
# 2987       Unimax Art Galleries
# 2988            Min Lin Diecast
# 2989   Highway 66 Mini Classics
# 2990          Red Start Diecast
# 2991       Unimax Art Galleries
# 2992  Welly Diecast Productions
# 2993      Autoart Studio Design
# 2994   Highway 66 Mini Classics
# 2995              Exoto Designs
#
#                                      productDescription quantityInStock  \
# 0     Die-cast model of the silver 1965 Aston Martin...            9042
# 1     Features include opening and closing doors. Co...            8164
# 2     This model features working front and rear sus...            8990
# 3     This diecast model of the 1966 Shelby Cobra 42...            8197
# 4     Official Moto Guzzi logos and insignias, saddl...            6625
# 5     Intricately detailed with chrome accents and t...            4357
# 6     This 1:24 scale precision die cast replica of ...            2847
# 7     This 1:18 scale replica of the 1917 Grand Tour...            2724
# 8     Features opening hood, opening doors, opening ...             540
# 9     This model features grille-mounted chrome horn...            9354
# 10    This 1:18 scale precision die cast replica fea...            6553
# 11    This 1:18 scale precision die-cast replica, wi...            3209
# 12    This model features rotating wheels, working s...            1005
# 13    This 1:24 scale die-cast replica of the 1939 C...            7332
# 14    This 1:24 scale precision die cast replica of ...            2847
# 15    Precision-engineered from original Jaguar spec...            2350
# 16    Precision crafted hand-assembled 1:18 scale re...            1452
# 17    1969 Z/28 Chevy Camaro 1:24 scale replica. The...            4695
# 18    The operating parts of this limited edition Di...            9446
# 19    This model features grille-mounted chrome horn...            2081
# 20    This model features, opening hood, opening doo...            3975
# 21    Die-cast model of the silver 1965 Aston Martin...            9042
# 22    This precision die-cast replica features openi...            8826
# 23    This model features, opening hood, opening doo...            9772
# 24    Features include opening and closing doors. Co...            8164
# 25    his replica features opening doors, superb det...            8347
# 26    This model features working front and rear sus...            8990
# 27    This diecast model of the 1966 Shelby Cobra 42...            8197
# 28    This replica features opening doors, superb de...            7723
# 29    Features include: Turnable front wheels; steer...            6600
# ...                                                 ...             ...
# 2966   Features opening trunk,  working steering system            7062
# 2967  Exact replia with official logos and insignias...            5841
# 2968  Exact replia with official logos and insignias...            7106
# 2969  10" Wingspan with retractable landing gears.Co...             551
# 2970  1:18 scale replica of actual Army's UH-60L BLA...            5330
# 2971      Has retractable wheels and comes with a stand             992
# 2972  Exact replica. Wood and Metal. Many extras inc...            4259
# 2973   Features opening trunk,  working steering system            3913
# 2974  Hand crafted wooden toy train set is in about ...            6450
# 2975  Features opening hood, opening doors, opening ...            2378
# 2976   Features opening trunk,  working steering system            8290
# 2977                       Official logos and insignias            3627
# 2978  All wood with canvas sails. Many extras includ...            1898
# 2979  Hand crafted diecast-like metal bi-plane is re...            5942
# 2980  This model features chrome trim and grille, op...            9173
# 2981  Chrome Trim, Chrome Grille, Opening Hood, Open...            6621
# 2982  All wood with canvas sails. Measures 31 1/2 in...            1897
# 2983  Measures 31 1/2 inches Long x 25 1/2 inches Hi...             737
# 2984  All wood with canvas sails. Measures 31 1/2" L...            7083
# 2985  Completed model measures 19 1/2 inches long, 9...            1956
# 2986  Exact replica. Wood and Metal. Many extras inc...            5088
# 2987  Measures 38 inches Long x 33 3/4 inches High. ...             414
# 2988  This replica features working kickstand, front...            7933
# 2989  Official Moto Guzzi logos and insignias, saddl...            6625
# 2990  Model features, official Harley Davidson logos...            5582
# 2991  Official logos and insignias, saddle bags loca...            9997
# 2992  Intricately detailed with chrome accents and t...            4357
# 2993  Detailed scale replica with working suspension...            7003
# 2994  Detailed scale replica with working suspension...              15
# 2995  Features official die-struck logos and baked e...             178
#
#      buyPrice    MSRP
# 0       65.96  124.44
# 1       56.76  132.00
# 2       62.16  141.28
# 3       29.18   50.31
# 4       68.99  118.94
# 5       24.23   60.57
# 6       20.61   44.80
# 7       86.70  170.00
# 8       33.30   60.54
# 9       58.48  127.13
# 10      43.26   92.03
# 11      34.21   71.27
# 12      49.24   73.49
# 13      22.57   33.19
# 14      20.61   44.80
# 15      47.25   90.87
# 16      72.82  117.44
# 17      50.51   85.61
# 18      62.11  107.08
# 19      21.75   41.03
# 20      83.51  141.54
# 21      65.96  124.44
# 22      53.90   77.00
# 23      93.89  142.25
# 24      56.76  132.00
# 25      77.90  169.34
# 26      62.16  141.28
# 27      29.18   50.31
# 28      16.24   37.76
# 29      98.30  140.43
# ...       ...     ...
# 2966    27.06   43.64
# 2967    51.15   91.34
# 2968    59.33  118.65
# 2969    54.40   80.00
# 2970    77.27  157.69
# 2971    49.00   84.48
# 2972    51.61   86.02
# 2973    68.30  136.59
# 2974    67.56  100.84
# 2975    64.58  105.87
# 2976    52.66   87.77
# 2977    66.74  109.42
# 2978    82.34  122.89
# 2979    34.25   68.51
# 2980    46.91   88.51
# 2981    48.64   83.86
# 2982    34.00   66.67
# 2983    43.30   86.61
# 2984    33.97   72.28
# 2985    51.09  100.17
# 2986    53.63   99.31
# 2987    33.30   54.60
# 2988    48.81   95.70
# 2989    68.99  118.94
# 2990    91.02  193.66
# 2991    66.27  150.62
# 2992    24.23   60.57
# 2993    60.86  112.70
# 2994    37.32   76.17
# 2995    66.92   99.89
#
# [2996 rows x 31 columns]

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lab, you practiced your knowledge on one-to-many and many-to-many relationships!
